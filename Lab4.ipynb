# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

sys.path.append('..')

# %%
image = cv.imread('../images/lr4.jpg', 0)
plt.imshow(image, cmap='gray')

# %%
thresh = cv.adaptiveThreshold(image, 255, cv.ADAPTIVE_THRESH_GAUSSIAN_C, cv.THRESH_BINARY, 15, 90)
plt.imshow(thresh, cmap='gray')

# %%
kernel = np.ones((8, 4), np.uint8)
opening = cv.morphologyEx(thresh, cv.MORPH_OPEN, kernel)
plt.imshow(opening, cmap='gray')

# %%
kernel = np.ones((6, 4), np.uint8)
erosion = cv.erode(thresh, kernel, iterations=1)
plt.imshow(erosion,cmap='gray')

# %% [markdown]
# # Ой, тогда я не буду писать жалобу
